# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## Ejercicio 1
# Dada la siguiente lista:
# > ```ejer_1 = [1,2,3,4,5]```
#
# Inviértela para que quede de la siguiente manera
# > ```ejer_1 = [5,4,3,2,1]```

# %%
ejer_1 = [1,2,3,4,5]

ejer_1.reverse()
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## Ejercicio 2
# Eleva todos los elementos de la lista al cuadrado
# > ```ejer_2 = [1,2,3,4,5]```

# %%
ejer_2 = [1,2,3,4,5]

ejer_2_al_cuadrado = []

for i in ejer_2:
    resultado = i ** 2
    ejer_2_al_cuadrado.append(resultado)
print(ejer_2_al_cuadrado)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## Ejercicio 3
# Crea una lista nueva con todas las combinaciones de las siguientes dos listas:
# > ```ejer_3_1 = ["Hola", "amigo"]```
# >
# > ```ejer_3_2 = ["Que", "tal"]```
#
# Obten el siguiente output:
#
# ['Hola Que', 'Hola tal', 'amigo Que', 'amigo tal']

# %%
ejer_3_1 = ["Hola", "amigo"]
ejer_3_2 = ["Que", "tal"]

nueva_lista = []

for i in ejer_3_1:
    for j in ejer_3_2:
        nueva_lista.append(i + " " + j)

print(nueva_lista)
# Out:
# ['Hola Que', 'Hola tal', 'amigo Que', 'amigo tal']

# %% [markdown]
# ## Ejercicio 4
# Dada la siguiente lista, encuentra el índice del valor 45 y sustitúyelo por el 0
# > ```ejer_4 = [20, 47, 19, 29, 45, 67, 78, 90]```

# %%
ejer_4 = [20, 47, 19, 29, 45, 67, 78, 90]

ejer_4[ejer_4.index(45)] = 0

print(ejer_4)
# Out:
# [20, 47, 19, 29, 0, 67, 78, 90]

# %% [markdown]
# ## Ejercicio 5
# Dada la siguiente lista, elimina todos los valores iguales a 3
# > ```ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]```
#
# Consejo: No intentes eliminar elementos sobre la lista que estás iterando. Haz una copia con `ejer_5.copy()`.

# %%
ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]

copia = ejer_5.copy()

for i in ejer_5:
    if i == 3:
        copia.remove(3)

print(copia)
# Out:
# [20, 47, 19, 29, 45, 67, 78, 90]

# %% [markdown]
# ## Ejercicio 6
# 1. Crea una tupla con 3 elementos
# 2. Crea otra tupla con un elemento y comprueba su tipo
# 3. Crea una tupla con elementos de diferentes tipos
# 4. Imprime por pantalla el primer y ultimo elemento de la tupla del apartado 3. Usa `len` para el ultimo
# 5. Añade un elemento a la tupla del apartado 3.
# 6. Eliminar un elemento de la tupla del apartado 5, que se encuentre más o menos en la mitad.
# 7. Convierte la tupla del apartado 5 en una lista

# %%
mi_tupla = (1, 2, 3) #apartado 1
 
tupla_1 = (4,) #apartado 2
print(type(tupla_1))

tupla_2 = (1, "hello", 3.14, True) # apartado 3

print(tupla_2[0]) #apartado 4
print(tupla_2[len(tupla_2) - 1])

tupla_3 = ("adios",) # apartado 5
tupla_4 = tupla_2 + tupla_3
print(tupla_4)

tupla_5 = tupla_4[:1] + tupla_4[2:] # apartado 6
print(tupla_5)

lista = list(tupla_4) # apartado 7
print(type(lista))
# Out:
# <class 'tuple'>
# 1
# True
# (1, 'hello', 3.14, True, 'adios')
# (1, 3.14, True, 'adios')
# <class 'list'>

# %% [markdown]
# ## Ejercicio 7
# Concatena todos los elementos de la tupla en un unico string. Para ello utiliza el metodo `.join()` de los Strings
# > ```ejer_7 = ("cien", "cañones", "por", "banda")```
#
# Resultado: `cien cañones por banda`

# %%
ejer_7 = ("cien", "cañones", "por", "banda")

resultado = " ".join(ejer_7) # 1ero se indica el separador y luego, dentro de la función join(), donde queremos estos nuevos separadores

print(resultado)
# Out:
# cien cañones por banda

# %% [markdown]
# ## Ejercicio 8
# Obten el tercer elemento de la siguiente tupla, y el tercero empezando por la cola
# > ```ejer_8 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3)```

# %%
ejer_8 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3)

print(ejer_8[2])
print(ejer_8[-3])
# Out:
# 3
# 90

# %% [markdown]
# ## Ejercicio 9
# 1. ¿Cuántas veces se repite el 3 en la siguiente tupla?
# 2. Crea una tupla nueva con los elementos desde la posicion 5 a la 10.
# 3. ¿Cuántos elementos tiene la tupla `ejer_9`?
# > ```ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)```

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)

print(ejer_9.count(3)) # apartado 1

ejer_9_nuevo = ejer_9[5:11] # apartado 2
print(ejer_9_nuevo)

len(ejer_9) # apartado 3
# Out:
# 7
# (3, 29, 45, 67, 78, 90)
# 26

# %% [markdown]
# ## Ejercicio 10
# Comprueba si el numero 60 esta en la tupla del ejercicio 9

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)

60 in ejer_9
# Out:
# False

# %% [markdown]
# ## Ejercicio 11
# 1. Convierte la tupla del apartado 10 en una lista
# 2. Convierte la tupla del apartado 10 en un set
# 3. Convierte la tupla del apartado 10 en un diccionario. Usa también los indices

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)

mi_lista = list(ejer_9)
print(type(mi_lista))

mi_set = set(ejer_9)
print(type(mi_set))

mi_dict = {}
for i, value in enumerate(ejer_9):
    mi_dict[i] = value

print(type(mi_dict))
# Out:
# <class 'list'>
# <class 'set'>
# <class 'dict'>

# %% [markdown]
# ## Ejercicio 12
# Convierte la siguiente tupla en un diccionario
# > ```ejer_12 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]```
#
# TIP: Puedes usar dos variables de control en un bucle `for`. Una por cada valor de las tuplas.

# %%
ejer_12 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]

mi_dict_2 = {}
for i, value in enumerate(ejer_12):
    mi_dict_2[i] = value

print(mi_dict_2)
print(type(mi_dict_2))
# Out:
# {0: ('x', 1), 1: ('x', 2), 2: ('x', 3), 3: ('y', 1), 4: ('y', 2), 5: ('z', 1)}
# <class 'dict'>

# %% [markdown]
# ## Ejercicio 13
# 1. Crea una lista ordenada ascendente con las claves del diccionario
# 2. Crea otra lista ordenada descendente con los valores
# 3. Añade una nueva clave/valor
# 4. Busca la clave 2 dentro del diccionario
# 5. Itera la clave y el valor del diccionario con un unico for
# > ```ejer_13 = {4:78, 2:98, 8:234, 5:29}```

# %%
ejer_13 = {4:78, 2:98, 8:234, 5:29} 

apartado1 = sorted(ejer_13.keys()) # apartado 1
print(apartado1)

apartado2 = sorted(ejer_13.values(), reverse = True) # apartado 2
print(apartado2)

ejer_13[3] = 11 # apartado 3
print(ejer_13)

2 in ejer_13

for key, value in ejer_13.items(): # apartado 4
    print(key, value)
# Out:
# [2, 4, 5, 8]
# [234, 98, 78, 29]
# {4: 78, 2: 98, 8: 234, 5: 29, 3: 11}
# 4 78
# 2 98
# 8 234
# 5 29
# 3 11

# %% [markdown]
# ## Ejercicio 14
# Junta ambos diccionarios. Para ello, utiliza `update`
# > ```ejer_14_1 = {1: 11, 2: 22}```
# >
# > ```ejer_14_2 = {3: 33, 4: 44}```

# %%
ejer_14_1 = {1: 11, 2: 22}

ejer_14_2 = {3: 33, 4: 44}

ejer_14_1.update(ejer_14_2)

print(ejer_14_1)
# Out:
# {1: 11, 2: 22, 3: 33, 4: 44}

# %% [markdown]
# ## Ejercicio 15
# Suma todos los valores del dicionario
# > ```ejer_15 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_15 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}

suma = sum(ejer_15.values())

print(suma)
# Out:
# 165

# %% [markdown]
# ## Ejercicio 16
# Multiplica todos los valores del diccionario
# > ```ejer_16 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_16 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}

producto = 1

for i in ejer_16.values():
    producto = producto * i 

print(producto)
# Out:
# 19326120

# %% [markdown]
# ## Ejercicio 17
# 1. Crea un set de tres elementos
# 2. Añade un cuarto
# 3. Elimina el utlimo elemento añadido
# 4. Elimina el elemento 10, si está presente. Usa `discard()`

# %%
mi_set = {1, 2, 3}

mi_set.add(4)

mi_set.discard(4)

mi_set.discard(10)

print(mi_set)
# Out:
# {1, 2, 3}
